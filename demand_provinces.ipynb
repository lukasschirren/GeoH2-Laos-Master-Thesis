# %%
import geopandas as gpd
import pandas as pd

# Load the shapefile
shapefile_path = "C:\\Users\\lukas\\OneDrive - Imperial College London\\0_Thesis\\1data_qgis\\Laos_Provinces\\provinces.shp"
gdf = gpd.read_file(shapefile_path)

# Calculate centroids manually
gdf['centroid'] = gdf.geometry.apply(lambda x: x.representative_point())

# Extract the province names and centroids
province_data = {
    'Province': gdf['NAME_1'],  # Replace 'Name' with the actual column name for province names if different
    'Latitude': gdf.centroid.y,
    'Longitude': gdf.centroid.x
}

# Create a DataFrame
df = pd.DataFrame(province_data)

# Save to Excel
file_path = 'Laos_Provinces_Centroids.xlsx'
df.to_excel(file_path, index=False)
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_27764\2026678187.py:14: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   'Latitude': gdf.centroid.y,
# C:\Users\lukas\AppData\Local\Temp\ipykernel_27764\2026678187.py:15: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   'Longitude': gdf.centroid.x

# %%
import folium
from IPython.display import display

# Load the Excel file
file_path = 'Laos_Provinces_Centroids.xlsx'
df = pd.read_excel(file_path)

# Create a map centered around Laos
laos_map = folium.Map(location=[18.2, 105.3], zoom_start=7)

# Add markers for each province
for index, row in df.iterrows():
    folium.Marker(s
        location=[row['Latitude'], row['Longitude']],
        popup=row['Province'],
        icon=folium.Icon(icon='info-sign')
    ).add_to(laos_map)

# Save the map to an HTML file
# laos_map.save('Laos_Provinces_Map.html')

# Display the map in the notebook
display(laos_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e32b1b55bf26c26397ca65d6507ac68 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e32b1b55bf26c26397ca65d6507ac68&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e32b1b55bf26c26397ca65d6507ac68 = L.map(
#                 &quot;map_9e32b1b55bf26c26397ca65d6507ac68&quot;,
#                 {
#                     center: [18.2, 105.3],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_54b6b774dfab7ab13cd4d797e2521d10 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_54b6b774dfab7ab13cd4d797e2521d10.addTo(map_9e32b1b55bf26c26397ca65d6507ac68);
#
#
#             var marker_f44a739d60433ae8df5555fb6e08dacc = L.marker(
#                 [14.79385453489457, 106.9450757412724],
#                 {}
#             ).addTo(map_9e32b1b55bf26c26397ca65d6507ac68);
#
#
#             var icon_22d9569fd9bc0c1a61a96bb60e2f516f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f44a739d60433ae8df5555fb6e08dacc.setIcon(icon_22d9569fd9bc0c1a61a96bb60e2f516f);
#
#
#         var popup_eaa9012f06c74ed6240c73be047cfc67 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b87111f4c00319a07ddbd533402a87a1 = $(`&lt;div id=&quot;html_b87111f4c00319a07ddbd533402a87a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Attapu&lt;/div&gt;`)[0];
#                 popup_eaa9012f06c74ed6240c73be047cfc67.setContent(html_b87111f4c00319a07ddbd533402a87a1);
#
#
#
#         marker_f44a739d60433ae8df5555fb6e08dacc.bindPopup(popup_eaa9012f06c74ed6240c73be047cfc67)
#         ;
#
#
#
#
#             var marker_77063739600e2f7ae8c6b7216a7103c3 = L.marker(
#                 [20.35105630267459, 100.6429066012492],
#                 {}
#             ).addTo(map_9e32b1b55bf26c26397ca65d6507ac68);
#
#
#             var icon_f06e237989df0654947d8f026638c0ec = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_77063739600e2f7ae8c6b7216a7103c3.setIcon(icon_f06e237989df0654947d8f026638c0ec);
#
#
#         var popup_abc01d046c559a5bb2c1a7a58bf2a46f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_164055869a71b99b35d916108ccbf8b8 = $(`&lt;div id=&quot;html_164055869a71b99b35d916108ccbf8b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bokeo&lt;/div&gt;`)[0];
#                 popup_abc01d046c559a5bb2c1a7a58bf2a46f.setContent(html_164055869a71b99b35d916108ccbf8b8);
#
#
#
#         marker_77063739600e2f7ae8c6b7216a7103c3.bindPopup(popup_abc01d046c559a5bb2c1a7a58bf2a46f)
#         ;
#
#
#
#
#             var marker_2914059abae037876a6b07fcc14df647 = L.marker(
#                 [18.48885756692305, 104.2596754658932],
#                 {}
#             ).addTo(map_9e32b1b55bf26c26397ca65d6507ac68);
#
#
#             var icon_8599836da741e727a2a43bd8b506d9e1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2914059abae037876a6b07fcc14df647.setIcon(icon_8599836da741e727a2a43bd8b506d9e1);
#
#
#         var popup_c7e96f476ed8aa86b5f5e906b60bda73 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_924ba0d9a2cd39a145bcd08364eff5f5 = $(`&lt;div id=&quot;html_924ba0d9a2cd39a145bcd08364eff5f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bolikhamxai&lt;/div&gt;`)[0];
#                 popup_c7e96f476ed8aa86b5f5e906b60bda73.setContent(html_924ba0d9a2cd39a145bcd08364eff5f5);
#
#
#
#         marker_2914059abae037876a6b07fcc14df647.bindPopup(popup_c7e96f476ed8aa86b5f5e906b60bda73)
#         ;
#
#
#
#
#             var marker_b016bc6158b4ef5ab9657d1cf239e75c = L.marker(
#                 [14.77168604344611, 105.9605640227714],
#                 {}
#             ).addTo(map_9e32b1b55bf26c26397ca65d6507ac68);
#
#
#             var icon_260cc590a93b83b10819d15bf683bcaf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&

# %%
provinces = pd.read_excel('Laos_Provinces_Centroids.xlsx')
provinces.iloc[:3]
# Out:
#       Province    Area   Latitude   Longitude
# 0      Attapeu   south  14.793855  106.945076
# 1        Bokeo   north  20.351056  100.642907
# 2  Bolikhamxai  centre  18.488858  104.259675

# %%
rice_production = pd.read_csv('FAO_rice_production_2022.csv')
rice_production = rice_production[['Province','harvested_2022','yield_2022','production_2022','production_average']]
rice_production.iloc[:3]
# Out:
#        Province  harvested_2022  yield_2022  production_2022  \
# 0         North             165         3.0              583
# 1     Phongsaly              16         3.0               53
# 2  Luang Namtha              20         3.0               52
#
#    production_average
# 0                 -17
# 1                 -22
# 2                  13

# %%
demand_province = pd.merge(provinces, rice_production, on='Province', how='inner')
demand_province
# Out:
#                 Province    Area   Latitude   Longitude  harvested_2022  \
# 0                Attapeu   south  14.793855  106.945076              22
# 1                  Bokeo   north  20.351056  100.642907              14
# 2            Bolikhamxai  centre  18.488858  104.259675              40
# 3              Champasak   south  14.771686  105.960564             106
# 4              Houaphanh   north  20.283857  104.009343              14
# 5             Khammouane  centre  17.569541  105.260559              85
# 6           Luang Namtha   north  20.888413  101.143448              20
# 7          Luang Prabang   north  20.132591  102.552408              38
# 8               Oudomxay   north  20.418031  101.729691              20
# 9              Phongsaly   north  21.654447  102.241823              16
# 10               Salavan   south  15.848394  106.273702              56
# 11           Savannakhet  centre  16.553723  105.705702             208
# 12             Vientiane  centre  18.630699  102.130948              58
# 13  Vientiane prefecture  centre  18.142883  102.580472              59
# 14            Sainyabuli   north  18.940634  101.346479              43
# 15            Xaisomboun  centre  18.884792  103.092177              94
# 16                Sekong   south  15.582019  107.039114               8
# 17          Xiangkhouang  centre  19.465685  103.519297              17
#
#     yield_2022  production_2022  production_average
# 0          4.0               88                   9
# 1          4.0               63                 -30
# 2          4.0              165                   3
# 3          4.0              464                  -4
# 4          3.0               65                 -40
# 5          4.0              322                  23
# 6          3.0               52                  13
# 7          3.0              100                   4
# 8          3.0               87                 -23
# 9          3.0               53                 -22
# 10         4.0              232                 -23
# 11         4.0              780                  11
# 12         4.0              236                  -5
# 13         4.0              235                 -13
# 14         3.0              163                 -18
# 15         0.0               36                 -17
# 16         4.0               34                  -3
# 17         4.0               97                 -23

# %%
sum_production_2022 = demand_province.production_2022.sum()
demand_province['weighted_avg'] = demand_province.production_2022 / sum_production_2022

# %%
hydrogen_demand = 200000
demand_province['demand_hydrogen'] = hydrogen_demand * demand_province['weighted_avg']
demand_province
# Out:
#                 Province    Area   Latitude   Longitude  harvested_2022  \
# 0                Attapeu   south  14.793855  106.945076              22
# 1                  Bokeo   north  20.351056  100.642907              14
# 2            Bolikhamxai  centre  18.488858  104.259675              40
# 3              Champasak   south  14.771686  105.960564             106
# 4              Houaphanh   north  20.283857  104.009343              14
# 5             Khammouane  centre  17.569541  105.260559              85
# 6           Luang Namtha   north  20.888413  101.143448              20
# 7          Luang Prabang   north  20.132591  102.552408              38
# 8               Oudomxay   north  20.418031  101.729691              20
# 9              Phongsaly   north  21.654447  102.241823              16
# 10               Salavan   south  15.848394  106.273702              56
# 11           Savannakhet  centre  16.553723  105.705702             208
# 12             Vientiane  centre  18.630699  102.130948              58
# 13  Vientiane prefecture  centre  18.142883  102.580472              59
# 14            Sainyabuli   north  18.940634  101.346479              43
# 15            Xaisomboun  centre  18.884792  103.092177              94
# 16                Sekong   south  15.582019  107.039114               8
# 17          Xiangkhouang  centre  19.465685  103.519297              17
#
#     yield_2022  production_2022  production_average  weighted_avg  \
# 0          4.0               88                   9      0.026895
# 1          4.0               63                 -30      0.019254
# 2          4.0              165                   3      0.050428
# 3          4.0              464                  -4      0.141809
# 4          3.0               65                 -40      0.019866
# 5          4.0              322                  23      0.098411
# 6          3.0               52                  13      0.015892
# 7          3.0              100                   4      0.030562
# 8          3.0               87                 -23      0.026589
# 9          3.0               53                 -22      0.016198
# 10         4.0              232                 -23      0.070905
# 11         4.0              780                  11      0.238386
# 12         4.0              236                  -5      0.072127
# 13         4.0              235                 -13      0.071822
# 14         3.0              163                 -18      0.049817
# 15         0.0               36                 -17      0.011002
# 16         4.0               34                  -3      0.010391
# 17         4.0               97                 -23      0.029645
#
#      demand_urea
# 0    5378.973105
# 1    3850.855746
# 2   10085.574572
# 3   28361.858191
# 4    3973.105134
# 5   19682.151589
# 6    3178.484108
# 7    6112.469438
# 8    5317.848411
# 9    3239.608802
# 10  14180.929095
# 11  47677.261614
# 12  14425.427873
# 13  14364.303178
# 14   9963.325183
# 15   2200.488998
# 16   2078.239609
# 17   5929.095355
